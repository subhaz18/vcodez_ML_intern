# %%
#lists Q1
l=[1,2,3,4,5]
print(l[0])
print(l[-1])
# Out:
# 1
# 5

# %%
#lists Q2
nums = [10, 20, 30, 40]
nums.append(50)
print(nums)
# Out:
# [10, 20, 30, 40, 50]

# %%
#lists Q3
fruits=["banana","cherry","mango"]
fruits.insert(2,"apple")
print(fruits)
# Out:
# ['banana', 'cherry', 'apple', 'mango']

# %%
#lists Q4
l=[2, 3, 2, 4, 2, 5]
while 2 in l:
  l.remove(2)
print(l)
# Out:
# [3, 4, 5]

# %%
#lists Q5
l=[2, 3, 2, 4, 2, 5]
print(l[::-1])
# Out:
# [5, 2, 4, 2, 3, 2]

# %%
#lists Q6
a = [1, 2, 3]
b = [4, 5, 6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#lists Q7
l=[3, 6, 2, 9, 1]
print(max(l))
print("ibdex of min element in the list:",l.index(min(l)))
# Out:
# 9
# ibdex of min element in the list: 4

# %%
#lists Q8
my_list = [1, 2, 2, 3, 4, 4, 5]
new_list = []
for item in my_list:
    if item not in new_list:
        new_list.append(item)
print(new_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuples Q1
t=("red","blue","green","yellow")
print(len(t))
# Out:
# 4

# %%
#tuples Q2
t = (5, 10, 15, 20)
print(t[1],t[-1])
# Out:
# 10 20

# %%
#tuples Q3
t = (5, 10, 15, 20)
if 15 in t:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
#tuples Q4
t=(1, 2, 3)
t=list(t)
t.append(4)
print(tuple(t))
# Out:
# (1, 2, 3, 4)

# %%
#tuples Q5
t=(10, 20, 30)
print(t.index(20))
# Out:
# 1

# %%
#tuples Q6
t=(1,2,3,4,5)
print(sum(t))
# Out:
# 15

# %%
#tuples Q7
#eg with list
l=[1,2,3,4,5]
l[2]=6
print(l)
#eg with tuple
t=(1,2,3,4,5)
t[2]=6
print(t)
# Out:
# [1, 2, 6, 4, 5]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-988597609.py in <cell line: 0>()
#       6 #eg with tuple
#       7 t=(1,2,3,4,5)
# ----> 8 t[2]=6
#       9 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#sets Q1
s={"chennai","trichy","coimbatore","madurai","kanyakumari"}
print(s)
# Out:
# {'madurai', 'chennai', 'kanyakumari', 'trichy', 'coimbatore'}

# %%
#sets Q2
s1={1,2,3,4,5}
s2={4,5,6,7,8}
print(s1.intersection(s2))
print(s1-s2)
# Out:
# {4, 5}
# {1, 2, 3}

# %%
#sets Q3
s={1, 3, 5, 7, 9}
if 7 in s:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
#sets Q4
s={1, 3, 5, 7, 9}
s.pop()
print(s)
#or
s.remove(3)
print(s)
#or
s.discard(5)
print(s)
# Out:
# {3, 5, 7, 9}
# {5, 7, 9}
# {7, 9}

# %%
l=[1, 2, 2, 3, 4, 4]
s=set(l)
print(s)
#sets doesnot allow duplicate enteries
# Out:
# {1, 2, 3, 4}

# %%
#sets Q6
s1 = {1, 2, 3, 4, 5}
s2 = {4, 5, 6, 7, 8}
sd = s1.symmetric_difference(s2)

print("Set 1:",s1)
print("Set 2:",s2)
print("Symmetric difference:",sd)
# Out:
# Set 1: {1, 2, 3, 4, 5}
# Set 2: {4, 5, 6, 7, 8}
# Symmetric difference: {1, 2, 3, 6, 7, 8}

# %%
#sets Q7
s={10, 20, 30}
s.add(40)
print(s)
s.clear()
print(s)
# Out:
# {40, 10, 20, 30}
# set()

# %%
#dict Q1
d={'name': 'subhash','age':21,'city':'chennai'}
print(d)
#or
for i,j in d.items():
  print(i,':',j)
# Out:
# {'name': 'subhash', 'age': 21, 'city': 'chennai'}
# name : subhash
# age : 21
# city : chennai

# %%
#dict Q2
info={"name":"john","age":25,"city":"delhi"}
print(info["age"])
info["age"]=35
print(info)
# Out:
# 25
# {'name': 'john', 'age': 35, 'city': 'delhi'}

# %%
#dict Q3
info={"name":"john","age":25,"city":"delhi"}
print(info)
info["country"]="india"
print(info)
# Out:
# {'name': 'john', 'age': 25, 'city': 'delhi'}
# {'name': 'john', 'age': 25, 'city': 'delhi', 'country': 'india'}

# %%
#dict Q4
i={'name': 'john', 'age': 25, 'city': 'delhi', 'country': 'india'}
i.pop("name")
print(i)
del i["city"]
print(i)
# Out:
# {'age': 25, 'city': 'delhi', 'country': 'india'}
# {'age': 25, 'country': 'india'}

# %%
#dict Q5
d={'name': 'john', 'age': 25, 'city': 'delhi', 'country': 'india'}
for i,j in d.items():
  print(i,":",j)
# Out:
# name : john
# age : 25
# city : delhi
# country : india

# %%
#dict Q6
marks = {"Math": 90, "English": 80, "Science": 85}
print(marks)
marks["English"]=88
print(marks)
# Out:
# {'Math': 90, 'English': 80, 'Science': 85}
# {'Math': 90, 'English': 88, 'Science': 85}

# %%
#dict Q6 b
d1={"x":1,"y":2}
d2={"z":3}
d3=d1.copy()
for k,v in d2.items():
  d3[k]=v
print(d3)

#or
d1={"x":1,"y":2}
d2={"z":3}
d1.update(d2)
print(d1)
# Out:
# {'x': 1, 'y': 2, 'z': 3}
# {'x': 1, 'y': 2, 'z': 3}

# %%
#dict Q7
d={'name': 'john', 'age': 25, 'city': 'delhi'}
if 'country' in d:
  pass
else:
  d['country'] = 'india'
print(d)
# Out:
# {'name': 'john', 'age': 25, 'city': 'delhi', 'country': 'india'}
