# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/crocodile_dataset.csv')

# %%
df
# Out:
#      Observation ID                             Common Name  \
# 0                 1                     Morelet's Crocodile
# 1                 2                      American Crocodile
# 2                 3                       Orinoco Crocodile
# 3                 4                     Morelet's Crocodile
# 4                 5      Mugger Crocodile (Marsh Crocodile)
# ..              ...                                     ...
# 995             996                  West African Crocodile
# 996             997             Hall's New Guinea Crocodile
# 997             998  West African Slender-snouted Crocodile
# 998             999  West African Slender-snouted Crocodile
# 999            1000             Hall's New Guinea Crocodile
#
#             Scientific Name        Family       Genus  Observed Length (m)  \
# 0      Crocodylus moreletii  Crocodylidae  Crocodylus                 1.90
# 1         Crocodylus acutus  Crocodylidae  Crocodylus                 4.09
# 2    Crocodylus intermedius  Crocodylidae  Crocodylus                 1.08
# 3      Crocodylus moreletii  Crocodylidae  Crocodylus                 2.42
# 4      Crocodylus palustris  Crocodylidae  Crocodylus                 3.75
# ..                      ...           ...         ...                  ...
# 995       Crocodylus suchus  Crocodylidae  Crocodylus                 2.55
# 996        Crocodylus halli  Crocodylidae  Crocodylus                 2.27
# 997  Mecistops cataphractus  Crocodylidae   Mecistops                 2.34
# 998  Mecistops cataphractus  Crocodylidae   Mecistops                 2.82
# 999        Crocodylus halli  Crocodylidae  Crocodylus                 1.73
#
#      Observed Weight (kg) Age Class      Sex Date of Observation  \
# 0                    62.0     Adult     Male          31-03-2018
# 1                   334.5     Adult     Male          28-01-2015
# 2                   118.2  Juvenile  Unknown          07-12-2010
# 3                    90.4     Adult     Male          01-11-2019
# 4                   269.4     Adult  Unknown          15-07-2019
# ..                    ...       ...      ...                 ...
# 995                 112.3     Adult   Female          01-10-2015
# 996                  80.3  Subadult   Female          25-01-2023
# 997                  93.5     Adult     Male          07-02-2014
# 998                 147.6     Adult     Male          09-07-2010
# 999                  47.4  Juvenile  Unknown          31-03-2014
#
#        Country/Region          Habitat Type    Conservation Status  \
# 0              Belize                Swamps          Least Concern
# 1           Venezuela             Mangroves             Vulnerable
# 2           Venezuela      Flooded Savannas  Critically Endangered
# 3              Mexico                Rivers          Least Concern
# 4               India                Rivers             Vulnerable
# ..                ...                   ...                    ...
# 995        Mauritania                 Lakes          Least Concern
# 996  Papua New Guinea   Freshwater Wetlands          Least Concern
# 997     Côte d'Ivoire                Swamps  Critically Endangered
# 998      Sierra Leone  Shaded Forest Rivers  Critically Endangered
# 999  Papua New Guinea   Freshwater Wetlands          Least Concern
#
#         Observer Name                                              Notes
# 0        Allison Hill           Cause bill scientist nation opportunity.
# 1        Brandon Hall  Ago current practice nation determine operatio...
# 2    Melissa Peterson  Democratic shake bill here grow gas enough ana...
# 3       Edward Fuller        Officer relate animal direction eye bag do.
# 4         Donald Reid  Class great prove reduce raise author play mov...
# ..                ...                                                ...
# 995       Karen Avery  Thousand position sense church out explain sig...
# 996     Sylvia Turner     Painting try talk like maintain serious style.
# 997   Kristin Fleming  Produce off light before majority garden milit...
# 998     Eric Petersen  Put everything our prove could party skin soon...
# 999    Kristen Harris  Ok community right then police day so store co...
#
# [1000 rows x 15 columns]

# %%
df.head(10)
# Out:
#    Observation ID                         Common Name         Scientific Name  \
# 0               1                 Morelet's Crocodile    Crocodylus moreletii
# 1               2                  American Crocodile       Crocodylus acutus
# 2               3                   Orinoco Crocodile  Crocodylus intermedius
# 3               4                 Morelet's Crocodile    Crocodylus moreletii
# 4               5  Mugger Crocodile (Marsh Crocodile)    Crocodylus palustris
# 5               6  Mugger Crocodile (Marsh Crocodile)    Crocodylus palustris
# 6               7                   Siamese Crocodile    Crocodylus siamensis
# 7               8               Congo Dwarf Crocodile     Osteolaemus osborni
# 8               9              West African Crocodile       Crocodylus suchus
# 9              10                 Morelet's Crocodile    Crocodylus moreletii
#
#          Family        Genus  Observed Length (m)  Observed Weight (kg)  \
# 0  Crocodylidae   Crocodylus                 1.90                  62.0
# 1  Crocodylidae   Crocodylus                 4.09                 334.5
# 2  Crocodylidae   Crocodylus                 1.08                 118.2
# 3  Crocodylidae   Crocodylus                 2.42                  90.4
# 4  Crocodylidae   Crocodylus                 3.75                 269.4
# 5  Crocodylidae   Crocodylus                 2.64                 137.4
# 6  Crocodylidae   Crocodylus                 2.85                 157.7
# 7  Crocodylidae  Osteolaemus                 0.35                   4.7
# 8  Crocodylidae   Crocodylus                 3.05                 201.2
# 9  Crocodylidae   Crocodylus                 3.39                 197.2
#
#   Age Class      Sex Date of Observation            Country/Region  \
# 0     Adult     Male          31-03-2018                    Belize
# 1     Adult     Male          28-01-2015                 Venezuela
# 2  Juvenile  Unknown          07-12-2010                 Venezuela
# 3     Adult     Male          01-11-2019                    Mexico
# 4     Adult  Unknown          15-07-2019                     India
# 5     Adult     Male          08-06-2023                     India
# 6  Subadult     Male          10-12-2010                  Thailand
# 7  Juvenile  Unknown          03-08-2008  Central African Republic
# 8     Adult     Male          16-04-2020                     Sudan
# 9     Adult     Male          21-05-2016                    Mexico
#
#        Habitat Type    Conservation Status          Observer Name  \
# 0            Swamps          Least Concern           Allison Hill
# 1         Mangroves             Vulnerable           Brandon Hall
# 2  Flooded Savannas  Critically Endangered       Melissa Peterson
# 3            Rivers          Least Concern          Edward Fuller
# 4            Rivers             Vulnerable            Donald Reid
# 5        Reservoirs             Vulnerable            Randy Brown
# 6       Slow Rivers  Critically Endangered  Dr. Marvin Thomas Jr.
# 7     Forest Swamps         Data Deficient          Terri Frazier
# 8             Lakes          Least Concern          Deborah Mason
# 9           Lagoons          Least Concern          Tamara George
#
#                                                Notes
# 0           Cause bill scientist nation opportunity.
# 1  Ago current practice nation determine operatio...
# 2  Democratic shake bill here grow gas enough ana...
# 3        Officer relate animal direction eye bag do.
# 4  Class great prove reduce raise author play mov...
# 5  Source husband at tree note responsibility def...
# 6  Much section investment on gun young catch man...
# 7  Race Mr environment political born itself law ...
# 8  Medical blood personal success medical current...
# 9  Affect upon these story film around there wate...

# %%
df.tail(10)
# Out:
#      Observation ID                             Common Name  \
# 990             991             Hall's New Guinea Crocodile
# 991             992                          Nile Crocodile
# 992             993  West African Slender-snouted Crocodile
# 993             994            West African Dwarf Crocodile
# 994             995                     Morelet's Crocodile
# 995             996                  West African Crocodile
# 996             997             Hall's New Guinea Crocodile
# 997             998  West African Slender-snouted Crocodile
# 998             999  West African Slender-snouted Crocodile
# 999            1000             Hall's New Guinea Crocodile
#
#             Scientific Name        Family        Genus  Observed Length (m)  \
# 990        Crocodylus halli  Crocodylidae   Crocodylus                 2.74
# 991    Crocodylus niloticus  Crocodylidae   Crocodylus                 3.13
# 992  Mecistops cataphractus  Crocodylidae    Mecistops                 2.26
# 993   Osteolaemus tetraspis  Crocodylidae  Osteolaemus                 0.39
# 994    Crocodylus moreletii  Crocodylidae   Crocodylus                 3.40
# 995       Crocodylus suchus  Crocodylidae   Crocodylus                 2.55
# 996        Crocodylus halli  Crocodylidae   Crocodylus                 2.27
# 997  Mecistops cataphractus  Crocodylidae    Mecistops                 2.34
# 998  Mecistops cataphractus  Crocodylidae    Mecistops                 2.82
# 999        Crocodylus halli  Crocodylidae   Crocodylus                 1.73
#
#      Observed Weight (kg) Age Class      Sex Date of Observation  \
# 990                 121.5     Adult     Male          28-03-2022
# 991                 285.8  Subadult     Male          14-07-2012
# 992                  88.5     Adult     Male          02-07-2007
# 993                   4.9  Juvenile   Female          29-01-2005
# 994                 159.5     Adult   Female          26-10-2017
# 995                 112.3     Adult   Female          01-10-2015
# 996                  80.3  Subadult   Female          25-01-2023
# 997                  93.5     Adult     Male          07-02-2014
# 998                 147.6     Adult     Male          09-07-2010
# 999                  47.4  Juvenile  Unknown          31-03-2014
#
#        Country/Region          Habitat Type    Conservation Status  \
# 990  Papua New Guinea                Rivers          Least Concern
# 991             Egypt            Reservoirs          Least Concern
# 992           Nigeria  Shaded Forest Rivers  Critically Endangered
# 993             Ghana         Forest Swamps             Vulnerable
# 994         Guatemala                Rivers          Least Concern
# 995        Mauritania                 Lakes          Least Concern
# 996  Papua New Guinea   Freshwater Wetlands          Least Concern
# 997     Côte d'Ivoire                Swamps  Critically Endangered
# 998      Sierra Leone  Shaded Forest Rivers  Critically Endangered
# 999  Papua New Guinea   Freshwater Wetlands          Least Concern
#
#        Observer Name                                              Notes
# 990      Casey Miles                              Head member activity.
# 991   Deborah Moreno                            They case TV team song.
# 992     John Mendoza  Common need phone teach audience project tax c...
# 993      Karen Fritz   Not east send style gun different energy arrive.
# 994      Seth Norman          Cover risk health last student different.
# 995      Karen Avery  Thousand position sense church out explain sig...
# 996    Sylvia Turner     Painting try talk like maintain serious style.
# 997  Kristin Fleming  Produce off light before majority garden milit...
# 998    Eric Petersen  Put everything our prove could party skin soon...
# 999   Kristen Harris  Ok community right then police day so store co...

# %%
df.sample(10)
# Out:
#      Observation ID                                Common Name  \
# 252             253  Central African Slender-snouted Crocodile
# 478             479                        Morelet's Crocodile
# 537             538                Hall's New Guinea Crocodile
# 931             932         Mugger Crocodile (Marsh Crocodile)
# 783             784                         American Crocodile
# 692             693                          Orinoco Crocodile
# 522             523                        Saltwater Crocodile
# 15               16                        Morelet's Crocodile
# 359             360               West African Dwarf Crocodile
# 709             710                Hall's New Guinea Crocodile
#
#              Scientific Name        Family        Genus  Observed Length (m)  \
# 252  Mecistops leptorhynchus  Crocodylidae    Mecistops                 2.86
# 478     Crocodylus moreletii  Crocodylidae   Crocodylus                 2.82
# 537         Crocodylus halli  Crocodylidae   Crocodylus                 1.00
# 931     Crocodylus palustris  Crocodylidae   Crocodylus                 3.97
# 783        Crocodylus acutus  Crocodylidae   Crocodylus                 3.18
# 692   Crocodylus intermedius  Crocodylidae   Crocodylus                 4.35
# 522       Crocodylus porosus  Crocodylidae   Crocodylus                 3.61
# 15      Crocodylus moreletii  Crocodylidae   Crocodylus                 2.00
# 359    Osteolaemus tetraspis  Crocodylidae  Osteolaemus                 0.15
# 709         Crocodylus halli  Crocodylidae   Crocodylus                 3.49
#
#      Observed Weight (kg)  Age Class      Sex Date of Observation  \
# 252                 164.1      Adult   Female          13-08-2005
# 478                 133.4      Adult   Female          17-05-2020
# 537                  37.4   Juvenile  Unknown          22-03-2009
# 931                 269.9      Adult   Female          12-08-2005
# 783                 215.0      Adult  Unknown          25-10-2010
# 692                 472.1      Adult   Female          01-06-2020
# 522                 399.7   Juvenile     Male          03-11-2010
# 15                   67.9      Adult  Unknown          18-03-2007
# 359                   5.4  Hatchling     Male          12-11-2025
# 709                 192.0      Adult     Male          17-05-2010
#
#        Country/Region         Habitat Type    Conservation Status  \
# 252             Gabon        Forest Rivers             Endangered
# 478         Guatemala              Lagoons          Least Concern
# 537  Papua New Guinea  Freshwater Wetlands          Least Concern
# 931         Sri Lanka              Marshes             Vulnerable
# 783              Cuba            Mangroves             Vulnerable
# 692         Venezuela         Large Rivers  Critically Endangered
# 522             India     Coastal Wetlands          Least Concern
# 15             Mexico               Rivers          Least Concern
# 359      Sierra Leone        Small Streams             Vulnerable
# 709  Papua New Guinea  Freshwater Wetlands          Least Concern
#
#            Observer Name                                              Notes
# 252          Marco Johns                      Head garden box hundred lead.
# 478  Christopher Vasquez  There car fish most center bring analysis camp...
# 537         Terry Glover  Country little reality level realize system no...
# 931      Caitlin Gilmore                  Indeed mother peace citizen need.
# 783          Noah Sparks  Story teacher size interesting sea few learn b...
# 692        Steven Fisher  Fish floor culture sort material wrong instead...
# 522         Yvonne Johns  Particular whatever five radio garden end sell...
# 15         Donald Wright  Kitchen technology nearly anything yourself st...
# 359       Randy Williams       Finally shoulder land phone brother capital.
# 709  David Rodriguez PhD  Quite fact direction me sense simple beyond so...

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.columns
# Out:
# Index(['Observation ID', 'Common Name', 'Scientific Name', 'Family', 'Genus',
#        'Observed Length (m)', 'Observed Weight (kg)', 'Age Class', 'Sex',
#        'Date of Observation', 'Country/Region', 'Habitat Type',
#        'Conservation Status', 'Observer Name', 'Notes'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Observation ID        1000 non-null   int64
#  1   Common Name           1000 non-null   object
#  2   Scientific Name       1000 non-null   object
#  3   Family                1000 non-null   object
#  4   Genus                 1000 non-null   object
#  5   Observed Length (m)   1000 non-null   float64
#  6   Observed Weight (kg)  1000 non-null   float64
#  7   Age Class             1000 non-null   object
#  8   Sex                   1000 non-null   object
#  9   Date of Observation   1000 non-null   object
#  10  Country/Region        1000 non-null   object
#  11  Habitat Type          1000 non-null   object
#  12  Conservation Status   1000 non-null   object
#  13  Observer Name         1000 non-null   object
#  14  Notes                 1000 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 117.3+ KB

# %%
df.dtypes
# Out:
# Observation ID            int64
# Common Name              object
# Scientific Name          object
# Family                   object
# Genus                    object
# Observed Length (m)     float64
# Observed Weight (kg)    float64
# Age Class                object
# Sex                      object
# Date of Observation      object
# Country/Region           object
# Habitat Type             object
# Conservation Status      object
# Observer Name            object
# Notes                    object
# dtype: object

# %%
df.describe()
# Out:
#        Observation ID  Observed Length (m)  Observed Weight (kg)
# count     1000.000000          1000.000000           1000.000000
# mean       500.500000             2.415110            155.771900
# std        288.819436             1.097542            175.186788
# min          1.000000             0.140000              4.400000
# 25%        250.750000             1.637500             53.225000
# 50%        500.500000             2.430000            100.600000
# 75%        750.250000             3.010000            168.875000
# max       1000.000000             6.120000           1139.700000

# %%
df.describe(include='all')
# Out:
#         Observation ID           Common Name          Scientific Name  \
# count      1000.000000                  1000                     1000
# unique             NaN                    18                       18
# top                NaN  New Guinea Crocodile  Crocodylus novaeguineae
# freq               NaN                    68                       68
# mean        500.500000                   NaN                      NaN
# std         288.819436                   NaN                      NaN
# min           1.000000                   NaN                      NaN
# 25%         250.750000                   NaN                      NaN
# 50%         500.500000                   NaN                      NaN
# 75%         750.250000                   NaN                      NaN
# max        1000.000000                   NaN                      NaN
#
#               Family       Genus  Observed Length (m)  Observed Weight (kg)  \
# count           1000        1000          1000.000000           1000.000000
# unique             1           3                  NaN                   NaN
# top     Crocodylidae  Crocodylus                  NaN                   NaN
# freq            1000         784                  NaN                   NaN
# mean             NaN         NaN             2.415110            155.771900
# std              NaN         NaN             1.097542            175.186788
# min              NaN         NaN             0.140000              4.400000
# 25%              NaN         NaN             1.637500             53.225000
# 50%              NaN         NaN             2.430000            100.600000
# 75%              NaN         NaN             3.010000            168.875000
# max              NaN         NaN             6.120000           1139.700000
#
#        Age Class      Sex Date of Observation    Country/Region Habitat Type  \
# count       1000     1000                1000              1000         1000
# unique         4        3                 936                47           29
# top        Adult  Unknown          03-11-2010  Papua New Guinea       Rivers
# freq         510      354                   3                97          165
# mean         NaN      NaN                 NaN               NaN          NaN
# std          NaN      NaN                 NaN               NaN          NaN
# min          NaN      NaN                 NaN               NaN          NaN
# 25%          NaN      NaN                 NaN               NaN          NaN
# 50%          NaN      NaN                 NaN               NaN          NaN
# 75%          NaN      NaN                 NaN               NaN          NaN
# max          NaN      NaN                 NaN               NaN          NaN
#
#        Conservation Status    Observer Name  \
# count                 1000             1000
# unique                   5              989
# top          Least Concern  Christina Davis
# freq                   384                2
# mean                   NaN              NaN
# std                    NaN              NaN
# min                    NaN              NaN
# 25%                    NaN              NaN
# 50%                    NaN              NaN
# 75%                    NaN              NaN
# max                    NaN              NaN
#
#                                                     Notes
# count                                                1000
# unique                                               1000
# top     Ok community right then police day so store co...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
df.isnull().sum()
# Out:
# Observation ID          0
# Common Name             0
# Scientific Name         0
# Family                  0
# Genus                   0
# Observed Length (m)     0
# Observed Weight (kg)    0
# Age Class               0
# Sex                     0
# Date of Observation     0
# Country/Region          0
# Habitat Type            0
# Conservation Status     0
# Observer Name           0
# Notes                   0
# dtype: int64

# %%
df['Family'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Observation ID, Common Name, Scientific Name, Family, Genus, Observed Length (m), Observed Weight (kg), Age Class, Sex, Date of Observation, Country/Region, Habitat Type, Conservation Status, Observer Name, Notes]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Family'].unique()
# Out:
# array(['Crocodylidae'], dtype=object)

# %%
df.nunique()
# Out:
# Observation ID          1000
# Common Name               18
# Scientific Name           18
# Family                     1
# Genus                      3
# Observed Length (m)      390
# Observed Weight (kg)     837
# Age Class                  4
# Sex                        3
# Date of Observation      936
# Country/Region            47
# Habitat Type              29
# Conservation Status        5
# Observer Name            989
# Notes                   1000
# dtype: int64

# %%
df['Notes'].value_counts()
# Out:
# Notes
# Ok community right then police day so store consumer positive.                 1
# Cause bill scientist nation opportunity.                                       1
# Ago current practice nation determine operation speak according.               1
# Democratic shake bill here grow gas enough analysis least by two.              1
# Officer relate animal direction eye bag do.                                    1
#                                                                               ..
# Teacher audience draw protect Democrat.                                        1
# Just military building different full open discover detail.                    1
# Close month parent who up sense ready.                                         1
# Affect upon these story film around there water beat magazine attorney set.    1
# Medical blood personal success medical current hear claim well.                1
# Name: count, Length: 1000, dtype: int64

# %%
df['Age Class'].min(), df['Age Class'].max(), df['Age Class'].max()
# Out:
# ('Adult', 'Subadult', 'Subadult')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Observation ID', 'Observed Length (m)', 'Observed Weight (kg)'], dtype='object')

# %%
df.select_dtypes(include='number').head()
# Out:
#    Observation ID  Observed Length (m)  Observed Weight (kg)
# 0               1                 1.90                  62.0
# 1               2                 4.09                 334.5
# 2               3                 1.08                 118.2
# 3               4                 2.42                  90.4
# 4               5                 3.75                 269.4

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Common Name', 'Scientific Name', 'Family', 'Genus', 'Age Class', 'Sex',
#        'Date of Observation', 'Country/Region', 'Habitat Type',
#        'Conservation Status', 'Observer Name', 'Notes'],
#       dtype='object')

# %%
df.select_dtypes(include='object').head()
# Out:
#                           Common Name         Scientific Name        Family  \
# 0                 Morelet's Crocodile    Crocodylus moreletii  Crocodylidae
# 1                  American Crocodile       Crocodylus acutus  Crocodylidae
# 2                   Orinoco Crocodile  Crocodylus intermedius  Crocodylidae
# 3                 Morelet's Crocodile    Crocodylus moreletii  Crocodylidae
# 4  Mugger Crocodile (Marsh Crocodile)    Crocodylus palustris  Crocodylidae
#
#         Genus Age Class      Sex Date of Observation Country/Region  \
# 0  Crocodylus     Adult     Male          31-03-2018         Belize
# 1  Crocodylus     Adult     Male          28-01-2015      Venezuela
# 2  Crocodylus  Juvenile  Unknown          07-12-2010      Venezuela
# 3  Crocodylus     Adult     Male          01-11-2019         Mexico
# 4  Crocodylus     Adult  Unknown          15-07-2019          India
#
#        Habitat Type    Conservation Status     Observer Name  \
# 0            Swamps          Least Concern      Allison Hill
# 1         Mangroves             Vulnerable      Brandon Hall
# 2  Flooded Savannas  Critically Endangered  Melissa Peterson
# 3            Rivers          Least Concern     Edward Fuller
# 4            Rivers             Vulnerable       Donald Reid
#
#                                                Notes
# 0           Cause bill scientist nation opportunity.
# 1  Ago current practice nation determine operatio...
# 2  Democratic shake bill here grow gas enough ana...
# 3        Officer relate animal direction eye bag do.
# 4  Class great prove reduce raise author play mov...

# %%
df[df['Observed Length (m)'].between(1,2)]
# Out:
#      Observation ID                         Common Name  \
# 0                 1                 Morelet's Crocodile
# 2                 3                   Orinoco Crocodile
# 10               11        West African Dwarf Crocodile
# 11               12                 Morelet's Crocodile
# 14               15        West African Dwarf Crocodile
# ..              ...                                 ...
# 974             975                   Orinoco Crocodile
# 976             977  Freshwater Crocodile (Johnstone's)
# 977             978         Hall's New Guinea Crocodile
# 980             981        West African Dwarf Crocodile
# 999            1000         Hall's New Guinea Crocodile
#
#             Scientific Name        Family        Genus  Observed Length (m)  \
# 0      Crocodylus moreletii  Crocodylidae   Crocodylus                 1.90
# 2    Crocodylus intermedius  Crocodylidae   Crocodylus                 1.08
# 10    Osteolaemus tetraspis  Crocodylidae  Osteolaemus                 1.22
# 11     Crocodylus moreletii  Crocodylidae   Crocodylus                 1.84
# 14    Osteolaemus tetraspis  Crocodylidae  Osteolaemus                 1.32
# ..                      ...           ...          ...                  ...
# 974  Crocodylus intermedius  Crocodylidae   Crocodylus                 1.73
# 976    Crocodylus johnstoni  Crocodylidae   Crocodylus                 1.32
# 977        Crocodylus halli  Crocodylidae   Crocodylus                 1.99
# 980   Osteolaemus tetraspis  Crocodylidae  Osteolaemus                 1.01
# 999        Crocodylus halli  Crocodylidae   Crocodylus                 1.73
#
#      Observed Weight (kg) Age Class      Sex Date of Observation  \
# 0                    62.0     Adult     Male          31-03-2018
# 2                   118.2  Juvenile  Unknown          07-12-2010
# 10                   15.8     Adult     Male          08-06-2018
# 11                   60.7     Adult     Male          19-10-2019
# 14                   19.2     Adult   Female          14-06-2010
# ..                    ...       ...      ...                 ...
# 974                 117.2  Juvenile  Unknown          14-03-2019
# 976                  27.3  Juvenile     Male          29-09-2012
# 977                  52.1  Juvenile     Male          23-12-2025
# 980                  11.3     Adult   Female          09-03-2012
# 999                  47.4  Juvenile  Unknown          31-03-2014
#
#        Country/Region         Habitat Type    Conservation Status  \
# 0              Belize               Swamps          Least Concern
# 2           Venezuela     Flooded Savannas  Critically Endangered
# 10            Liberia        Small Streams             Vulnerable
# 11             Belize              Lagoons          Least Concern
# 14      Côte d'Ivoire        Small Streams             Vulnerable
# ..                ...                  ...                    ...
# 974         Venezuela     Flooded Savannas  Critically Endangered
# 976         Australia               Gorges          Least Concern
# 977  Papua New Guinea               Rivers          Least Concern
# 980      Sierra Leone        Small Streams             Vulnerable
# 999  Papua New Guinea  Freshwater Wetlands          Least Concern
#
#         Observer Name                                              Notes
# 0        Allison Hill           Cause bill scientist nation opportunity.
# 2    Melissa Peterson  Democratic shake bill here grow gas enough ana...
# 10      Betty Alvarez             Close month parent who up sense ready.
# 11    Jennifer Powers  Just military building different full open dis...
# 14      Matthew Lucas                I fund technology eat couple large.
# ..                ...                                                ...
# 974      Brianna Moss  Imagine oil head work should challenge pull th...
# 976    Michael Miller  Thing wrong name mind offer effort nearly walk...
# 977      Rachel Burns  Rule someone nature house prevent hotel office...
# 980       David Tapia  War product action our gas heart field people ...
# 999    Kristen Harris  Ok community right then police day so store co...
#
# [235 rows x 15 columns]

# %%
df.groupby('Scientific Name')['Sex'].max()
# Out:
# Scientific Name
# Crocodylus acutus          Unknown
# Crocodylus halli           Unknown
# Crocodylus intermedius     Unknown
# Crocodylus johnstoni       Unknown
# Crocodylus mindorensis     Unknown
# Crocodylus moreletii       Unknown
# Crocodylus niloticus       Unknown
# Crocodylus novaeguineae    Unknown
# Crocodylus palustris       Unknown
# Crocodylus porosus         Unknown
# Crocodylus raninus         Unknown
# Crocodylus rhombifer       Unknown
# Crocodylus siamensis       Unknown
# Crocodylus suchus          Unknown
# Mecistops cataphractus     Unknown
# Mecistops leptorhynchus    Unknown
# Osteolaemus osborni        Unknown
# Osteolaemus tetraspis      Unknown
# Name: Sex, dtype: object
